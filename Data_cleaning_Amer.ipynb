# %% [markdown]
# <a href="https://colab.research.google.com/github/ameraizam31-human/Python_NX_AC/blob/main/Data_cleaning_Amer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Dataset 1 : https://raw.githubusercontent.com/yashy1626/ds_dataset/refs/heads/main/ufo.csv

# Dataset 2 : https://raw.githubusercontent.com/yashy1626/ds_dataset/refs/heads/main/sample11.csv

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

ufo = pd.read_csv('https://raw.githubusercontent.com/yashy1626/ds_dataset/refs/heads/main/ufo.csv')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18241 entries, 0 to 18240
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City             18215 non-null  object
#  1   Colors Reported  2882 non-null   object
#  2   Shape Reported   15597 non-null  object
#  3   State            18241 non-null  object
#  4   Time             18241 non-null  object
# dtypes: object(5)
# memory usage: 712.7+ KB

# %%
ufo.isnull().sum()
# Out:
# City                  26
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
ufo.dropna().shape
# Out:
# (2486, 5)

# %%
ufo['City'].fillna(value='CityNotMentioned',inplace=True)

# %%
ufo['Colors Reported'].fillna(value='ColorsNotKnown',inplace=True)
ufo['Shape Reported'].fillna(value='UnknownShape',inplace=True)

# %%
ufo.isnull().sum()
# Out:
# City               0
# Colors Reported    0
# Shape Reported     0
# State              0
# Time               0
# dtype: int64

# %%
data = pd.read_csv("https://raw.githubusercontent.com/yashy1626/ds_dataset/refs/heads/main/sample11.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Id          7 non-null      int64
#  1   Name        7 non-null      object
#  2   Marks       5 non-null      float64
#  3   Percentage  3 non-null      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 356.0+ bytes

# %%
data
# Out:
#    Id  Name  Marks  Percentage
# 0   1  Alex   78.0        78.0
# 1   2  Alex   23.0         NaN
# 2   3  Alex    NaN        67.0
# 3   4  Alex   12.0         NaN
# 4   5  Alex    NaN         NaN
# 5   6  Alex   54.0         NaN
# 6   7  Alex   65.0        66.0

# %%
data.isnull().sum()
# Out:
# Id            0
# Name          0
# Marks         2
# Percentage    4
# dtype: int64

# %%
data['Marks'].fillna(method='bfill',inplace=True)

# %%
data['Percentage'].fillna(method='ffill',inplace=True)

# %%
data
# Out:
#    Id  Name  Marks  Percentage
# 0   1  Alex   78.0        78.0
# 1   2  Alex   23.0        78.0
# 2   3  Alex   12.0        67.0
# 3   4  Alex   12.0        67.0
# 4   5  Alex   54.0        67.0
# 5   6  Alex   54.0        67.0
# 6   7  Alex   65.0        66.0

# %%
data = pd.read_csv("https://raw.githubusercontent.com/yashy1626/ds_dataset/refs/heads/main/sample11.csv")
data
# Out:
#    Id  Name  Marks  Percentage
# 0   1  Alex   78.0        78.0
# 1   2  Alex   23.0         NaN
# 2   3  Alex    NaN        67.0
# 3   4  Alex   12.0         NaN
# 4   5  Alex    NaN         NaN
# 5   6  Alex   54.0         NaN
# 6   7  Alex   65.0        66.0

# %%
mean_val_marks = data['Marks'].mean()
data['Marks'].fillna(value=mean_val_marks,inplace=True)
data
# Out:
#    Id  Name  Marks  Percentage
# 0   1  Alex   78.0        78.0
# 1   2  Alex   23.0         NaN
# 2   3  Alex   46.4        67.0
# 3   4  Alex   12.0         NaN
# 4   5  Alex   46.4         NaN
# 5   6  Alex   54.0         NaN
# 6   7  Alex   65.0        66.0

# %%
mean_val_per = data['Percentage'].mean()
mean_val_per = round(mean_val_per,1)
data['Percentage'].fillna(value=mean_val_per,inplace=True)
data
# Out:
#    Id  Name  Marks  Percentage
# 0   1  Alex   78.0        78.0
# 1   2  Alex   23.0        70.3
# 2   3  Alex   46.4        67.0
# 3   4  Alex   12.0        70.3
# 4   5  Alex   46.4        70.3
# 5   6  Alex   54.0        70.3
# 6   7  Alex   65.0        66.0

# %%
data = pd.read_csv("https://raw.githubusercontent.com/yashy1626/ds_dataset/refs/heads/main/sample11.csv")
data
# Out:
#    Id  Name  Marks  Percentage
# 0   1  Alex   78.0        78.0
# 1   2  Alex   23.0         NaN
# 2   3  Alex    NaN        67.0
# 3   4  Alex   12.0         NaN
# 4   5  Alex    NaN         NaN
# 5   6  Alex   54.0         NaN
# 6   7  Alex   65.0        66.0

# %%
data.interpolate()
# Out:
#    Id  Name  Marks  Percentage
# 0   1  Alex   78.0       78.00
# 1   2  Alex   23.0       72.50
# 2   3  Alex   17.5       67.00
# 3   4  Alex   12.0       66.75
# 4   5  Alex   33.0       66.50
# 5   6  Alex   54.0       66.25
# 6   7  Alex   65.0       66.00

# %%
data = {
      'StudentName': ['Mark', 'Ali', 'Bob', 'John', 'Johny', 'Mark'],
      'Score': [45, 65, 76, 44, 39, 45]
}
df = pd.DataFrame(data)
df
# Out:
#   StudentName  Score
# 0        Mark     45
# 1         Ali     65
# 2         Bob     76
# 3        John     44
# 4       Johny     39
# 5        Mark     45

# %%
print(df.duplicated().sum())
# Out:
# 1

# %%
df[df.duplicated()]
# Out:
#   StudentName  Score
# 5        Mark     45

# %%
df[df['StudentName']=='Mark']
# Out:
#   StudentName  Score
# 0        Mark     45
# 5        Mark     45

# %%
df.drop_duplicates(inplace=True)

# %%
data = {
      'StudentName': ['Mark', 'Ali', 'Bob', 'John', 'Johny', 'Mark'],
      'Score': [45, 65, 76, 44, 39, 45]
}
df = pd.DataFrame(data)
df
# Out:
#   StudentName  Score
# 0        Mark     45
# 1         Ali     65
# 2         Bob     76
# 3        John     44
# 4       Johny     39
# 5        Mark     45

# %%
df.drop_duplicates(keep='last',inplace=True)
df
# Out:
#   StudentName  Score
# 1         Ali     65
# 2         Bob     76
# 3        John     44
# 4       Johny     39
# 5        Mark     45
